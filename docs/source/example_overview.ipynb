# %% [markdown]
# # Overview plot [^download]
#
# [^download]: This notebook can be downloaded as **{nb-download}`example_overview.ipynb`**.
#
# This very simple example shows you how to make an overview plot provided a yaml configuration file and a result csv.

# %%
from osekit import setup_logging
from pathlib import Path
import matplotlib.pyplot as plt
from post_processing.dataclass.data_aplose import DataAplose

setup_logging("bonjour.yaml")
setup_logging(Path().cwd().parents[1] / "src" / "post_processing" / "logging_config.yaml")

yaml_file = Path(r"_static/APOCADO_yaml.yml")
data = DataAplose.from_yaml(file=yaml_file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 7
#       4 from post_processing.dataclass.data_aplose import DataAplose
#       6 setup_logging("bonjour.yaml")
# ----> 7 setup_logging(Path().cwd().parents[1] / "src" / "post_processing" / "logging_config.yaml")
#       9 yaml_file = Path(r"_static/APOCADO_yaml.yml")
#      10 data = DataAplose.from_yaml(file=yaml_file)
#
# File ~\Documents\Git\OSmOSE\OSEkit\src\osekit\__init__.py:46, in setup_logging(config_file, default_level)
#      36 config_file_path = next(
#      37     (
#      38         file
#    (...)     42     None,
#      43 )
#      45 if config_file_path:
# ---> 46     with Path.open(config_file_path) as configuration:
#      47         logging_config = yaml.safe_load(configuration)
#      48     logging.config.dictConfig(logging_config)
#
# KeyboardInterrupt:

# %% [markdown]
# The `DataAplose` object has informations about the loaded result csv

# %%
print(f"{' FILE ':#^60}")
print(f"{'Begin:':<30}{str(data.begin):>30}")
print(f"{'End:':<30}{str(data.end):>30}")
print(f"{'Annotators:':<30}{str((', ').join(data.annotators)):>30}")
print(f"{'Labels:':<30}{str((', ').join(data.labels)):>30}")
print(f"{'Dataset:':<30}{str((', ').join(data.dataset)):>30}")
# Out:
# ########################### FILE ###########################
# Begin:                             2022-07-07 10:01:00+02:00
# End:                               2022-07-07 11:49:00+02:00
# Annotators:                           annotator1, annotator2
# Labels:                                 buzz, click, whistle
# Dataset:                                            dataset1

# %% [markdown]
# To create an overview plot of `data`, use the `post_processing.dataclass.data_aplose.DataAplose.overview` class method.
#
# The plot provides the number of annotation per label and per annotator.

# %%
data.overview()
# plt.show()
# Out:
# [INFO] - 25/09/11 09:33:48
# ############### Overview ###############
#
#              annotator2  annotator1
# annotation
# buzz                42          28
# click               80          60
# whistle             22          24
