# %%
from pathlib import Path

from pandas import (
    read_csv,
    to_datetime,
)

from post_processing.dataclass.data_aplose import DataAplose
from post_processing.utils.fpod_utils import resample_dpm, feeding_buzz, txt_folder, build_range

# %% [markdown]
# ### Load data

# %%
yaml_file = Path(r"user_case\resource\CPOD-FPOD_yaml.yml")
data_list = DataAplose.from_yaml(file=yaml_file)

fb_files = Path(r"U:\fb_fpod_cetiroise_c")  #Path to your click details folder.
d_beg_end = read_csv(r"U:\Deb_Fin_CETIROISE.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 yaml_file = Path("user_case/resource/CPOD-FPOD_yaml.yml").resolve()
# ----> 2 data_list = DataAplose.from_yaml(file=yaml_file)
#       4 fb_files = Path(r"U:\fb_fpod_cetiroise_c")  #Path to your click details folder.
#       5 d_beg_end = read_csv(r"U:\Deb_Fin_CETIROISE.csv")
#
# File ~\PycharmProjects\OSmOSE_post_processing\src\post_processing\dataclass\data_aplose.py:410, in DataAplose.from_yaml(cls, file, concat)
#     388 @classmethod
#     389 def from_yaml(
#     390     cls,
#     391     file: Path,
#     392     concat: bool = False,
#     393 ) -> DataAplose | list[DataAplose]:
#     394     """Return a DataAplose object from a yaml file.
#     395
#     396     Parameters
#    (...)    408
#     409     """
# --> 410     filters = DetectionFilter.from_yaml(file=file)
#     411     return cls.from_filters(filters, concat)
#
# File ~\PycharmProjects\OSmOSE_post_processing\src\post_processing\dataclass\detection_filter.py:64, in DetectionFilter.from_yaml(cls, file)
#      46 @classmethod
#      47 def from_yaml(
#      48     cls,
#      49     file: Path,
#      50 ) -> DetectionFilter | list[DetectionFilter]:
#      51     """Return a DetectionFilter object from a yaml file.
#      52
#      53     Parameters
#    (...)     62
#      63     """
# ---> 64     with file.open(encoding="utf-8") as yaml_file:
#      65         parameters = yaml.safe_load(yaml_file)
#      66         return cls.from_dict(parameters)
#
# File ~\AppData\Roaming\uv\python\cpython-3.12.11-windows-x86_64-none\Lib\pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\fouinel\\PycharmProjects\\OSmOSE_post_processing\\user_case\\resource\\user_case\\resource\\CPOD-FPOD_yaml.yml'

# %% [markdown]
# ### Data metric
# Here you need to choose the format in which you want to visualise the positive detections. This aims to replace the functionalities available in Chelonia's softwares.

# %%
frq = "D" #This argument will determine the format in which you want to visualise your data. Use "D", "h" or "10min".

# %%
resamp = resample_dpm(data_list.df, frq=frq, extra_columns=["deploy.name"])

# %% [markdown]
# ### Feeding buzzes processing
# Use "Marsouin" or "Commerson" to get different ICI processing.

# %%
fb_files = Path(r"U:\fb_fpod_cetiroise_c") #Path to your click details folder.
fb_all = txt_folder(fb_files)
fb_all = feeding_buzz(fb_all, "Marsouin")

fb_all["start_datetime"] = fb_all["start_datetime"].dt.floor(frq)
fb = fb_all.groupby("start_datetime")["Foraging"].sum().reset_index()
fb["start_datetime"] = to_datetime(fb["start_datetime"], utc=True)

dpm_fb = resamp.merge(fb, on="start_datetime", how="left")

# %%
d_0 = build_range(d_beg_end, frq)
d_tot = d_0.merge(dpm_fb, on=["start_datetime", "deploy.name"], how="left")

# %%
d_tot[["DPM","Foraging"]] = d_tot[["DPM","Foraging"]].fillna(0)
